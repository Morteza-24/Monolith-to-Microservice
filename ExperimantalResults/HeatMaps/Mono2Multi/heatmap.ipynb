# %% [markdown]
# ```
# python ../../../Mono2Multi_expt.py -p ../../../Test_Projects/PetClinic/src/ --alpha 1 --n-clusters 2 10 --threshold 0.1 0.9 --n-exec 10 -o alpha1.json -e ICP NED IFN SM Precision SR -k 7
# ```

# %%
from utils import *

json_file = "alpha1.json"

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "ICP")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="Reds", cbarlabel="ICP")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "NED")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="Reds", cbarlabel="NED")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "IFN")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="Reds", cbarlabel="IFN")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "SM")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="YlGn", cbarlabel="SM")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "Precision")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="YlGn", cbarlabel="Precision")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters

# %%
values, l_thresholds, l_clusters = prepare_data(json_file, "SR@7")
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (12,12)
im, cbar = heatmap(values, l_thresholds, l_clusters, ax=ax, cmap="YlGn", cbarlabel="SR@7")
texts = annotate_heatmap(im)
ax.set_title("number of clusters", loc="center")
ax.set_ylabel("membership threshold")
fig.tight_layout()
plt.show()
# Out:
# (0.55, 2) actaully has 1 cluters
# (0.6, 2) actaully has 1 cluters
# (0.65, 2) actaully has 1 cluters
# (0.7, 2) actaully has 1 cluters
# (0.75, 2) actaully has 1 cluters
# (0.8, 2) actaully has 1 cluters
# (0.85, 2) actaully has 1 cluters
# (0.35, 3) actaully has 4 cluters
# (0.5, 3) actaully has 2 cluters
# (0.55, 3) actaully has 2 cluters
# (0.6, 3) actaully has 1 cluters
# (0.65, 3) actaully has 1 cluters
# (0.7, 3) actaully has 1 cluters
# (0.75, 3) actaully has 1 cluters
# (0.8, 3) actaully has 1 cluters
# (0.85, 3) actaully has 1 cluters
# (0.3, 4) actaully has 5 cluters
# (0.35, 4) actaully has 5 cluters
# (0.4, 4) actaully has 2 cluters
# (0.45, 4) actaully has 2 cluters
# (0.5, 4) actaully has 1 cluters
# (0.55, 4) actaully has 1 cluters
# (0.6, 4) actaully has 1 cluters
# (0.65, 4) actaully has 1 cluters
# (0.7, 4) actaully has 1 cluters
# (0.75, 4) actaully has 1 cluters
# (0.8, 4) actaully has 1 cluters
# (0.85, 4) actaully has 1 cluters
# (0.25, 5) actaully has 6 cluters
# (0.3, 5) actaully has 6 cluters
# (0.35, 5) actaully has 6 cluters
# (0.4, 5) actaully has 4 cluters
# (0.45, 5) actaully has 4 cluters
# (0.5, 5) actaully has 1 cluters
# (0.55, 5) actaully has 1 cluters
# (0.6, 5) actaully has 1 cluters
# (0.65, 5) actaully has 1 cluters
# (0.7, 5) actaully has 1 cluters
# (0.75, 5) actaully has 1 cluters
# (0.8, 5) actaully has 1 cluters
# (0.85, 5) actaully has 1 cluters
# (0.2, 6) actaully has 7 cluters
# (0.25, 6) actaully has 7 cluters
# (0.3, 6) actaully has 3 cluters
# (0.35, 6) actaully has 3 cluters
# (0.4, 6) actaully has 1 cluters
# (0.45, 6) actaully has 1 cluters
# (0.5, 6) actaully has 1 cluters
# (0.55, 6) actaully has 1 cluters
# (0.6, 6) actaully has 1 cluters
# (0.65, 6) actaully has 1 cluters
# (0.7, 6) actaully has 1 cluters
# (0.75, 6) actaully has 1 cluters
# (0.8, 6) actaully has 1 cluters
# (0.85, 6) actaully has 1 cluters
# (0.2, 7) actaully has 5 cluters
# (0.25, 7) actaully has 5 cluters
# (0.3, 7) actaully has 2 cluters
# (0.35, 7) actaully has 2 cluters
# (0.4, 7) actaully has 2 cluters
# (0.45, 7) actaully has 2 cluters
# (0.5, 7) actaully has 1 cluters
# (0.55, 7) actaully has 1 cluters
# (0.6, 7) actaully has 1 cluters
# (0.65, 7) actaully has 1 cluters
# (0.7, 7) actaully has 1 cluters
# (0.75, 7) actaully has 1 cluters
# (0.8, 7) actaully has 1 cluters
# (0.85, 7) actaully has 1 cluters
# (0.25, 8) actaully has 7 cluters
# (0.3, 8) actaully has 3 cluters
# (0.35, 8) actaully has 3 cluters
# (0.4, 8) actaully has 2 cluters
# (0.45, 8) actaully has 1 cluters
# (0.5, 8) actaully has 1 cluters
# (0.55, 8) actaully has 1 cluters
# (0.6, 8) actaully has 1 cluters
# (0.65, 8) actaully has 1 cluters
# (0.7, 8) actaully has 1 cluters
# (0.75, 8) actaully has 1 cluters
# (0.8, 8) actaully has 1 cluters
# (0.85, 8) actaully has 1 cluters
# (0.15, 9) actaully has 10 cluters
# (0.2, 9) actaully has 10 cluters
# (0.25, 9) actaully has 8 cluters
# (0.3, 9) actaully has 3 cluters
# (0.35, 9) actaully has 2 cluters
# (0.4, 9) actaully has 2 cluters
# (0.45, 9) actaully has 1 cluters
# (0.5, 9) actaully has 1 cluters
# (0.55, 9) actaully has 1 cluters
# (0.6, 9) actaully has 1 cluters
# (0.65, 9) actaully has 1 cluters
# (0.7, 9) actaully has 1 cluters
# (0.75, 9) actaully has 1 cluters
# (0.8, 9) actaully has 1 cluters
# (0.85, 9) actaully has 1 cluters
