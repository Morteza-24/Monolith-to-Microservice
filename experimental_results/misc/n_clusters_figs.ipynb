# %% [markdown]
# ```
# python ../../Mono2Multi_expt.py -p ../../test_projects/PetClinic/src/ --alpha 1 --n-clusters 2 10 --threshold 0.45 --n-exec 10 -o alpha1threshold45exec10.json -e ICP NED IFN SM Precision SR -k 7
# ```

# %%
import matplotlib.pyplot as plt
import json
with open("Json_Files/alpha1threshold45exec10.json", "rt") as f:
    data = json.load(f)

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["ICP"])
plt.ylabel("ICP")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["NED"])
plt.ylabel("NED")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["IFN"])
plt.ylabel("IFN")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["SM"])
plt.ylabel("SM")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["Precision"])
plt.ylabel("Precision")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["n_clusters"])
    y.append(field["SR@7"])
plt.ylabel("SR@7")
plt.xlabel("n_clusters")
plt.plot(x,y, "-o")
