# %% [markdown]
# ```
# python ../../Mono2Multi_expt.py -p ../../test_projects/PetClinic/src/ --alpha 1 --n-clusters 4 --threshold 0.1 0.9 --n-exec 10 -o alpha1clusters4exec10.json -e ICP NED IFN SM Precision SR -k 7
# ```

# %%
import matplotlib.pyplot as plt
import json
with open("Json_Files/alpha1clusters4exec10.json", "rt") as f:
    data = json.load(f)

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["ICP"])
plt.ylabel("ICP")
plt.xlabel("threshold")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["NED"])
plt.ylabel("NED")
plt.xlabel("threshold")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["IFN"])
plt.ylabel("IFN")
plt.xlabel("threshold")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["SM"])
plt.ylabel("SM")
plt.xlabel("threshold")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["Precision"])
plt.ylabel("Precision")
plt.xlabel("threshold")
plt.plot(x,y, "-o")

# %%
x, y = [], []
for field in data:
    x.append(field["threshold"])
    y.append(field["SR@7"])
plt.ylabel("SR@7")
plt.xlabel("threshold")
plt.plot(x,y, "-o")
