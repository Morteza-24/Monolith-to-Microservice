# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.DataFrame()
projects = ["JPetStore", "DayTrader", "AcmeAir", "Plants"]
methods = ["Mo2oM", "HDBSCAN", "CoGCN", "Mono2Micro", "FoSCI", "MEM", "Bunch"]#, "Mono2Multi"
methods.reverse()
metrics = ["SM", "ICP", "IFN", "NED"]
explanation = {
	"SM": " (higher is better)",
	"ICP": " (lower is better)",
	"IFN": " (lower is better)",
	"NED": " (lower is better)"
}
for project in projects:
	for method in methods:
		with open(f"../results/{method}/{method}_{project}.json", "r") as f:
			data = json.load(f)
			new_df = pd.DataFrame(data)[metrics]
			new_df["Project"] = project
			new_df["Method"] = method#.replace("HDBSCAN", "$\\epsilon$-DBSCAN").replace("Mo2oM", "\\textbf{Mo2oM}\n\\textbf{(ours)}")
			df = pd.concat([df, new_df])

# %%
table_head = r'''\begin{table}[ht]
	\centering
	\begin{tabular}{lcccc}
		\hline
		& \multicolumn{4}{c}{\textbf{Projects}} \\
		\cline{2-5}
		\textbf{Model} & \textbf{JPetStore} & \textbf{DayTrader} & \textbf{AcmeAir} & \textbf{Plants} \\
		\hline'''
table_tail = r'''		\hline
	\end{tabular}
	\caption{Model performance on different projects (mean, median ± variance).}
	\label{tab:model-performance-metric}
\end{table}'''

# %%
for metric in metrics:
	print(f"\\center{{\\textbf{{{metric}, {explanation[metric]}}}}}")
	print()
	method_results = []
	for method in methods:
		proj_results = {}
		for project in projects:
			mean = np.mean(df[(df["Project"] == project) & (df["Method"] == method)][metric])
			median = np.median(df[(df["Project"] == project) & (df["Method"] == method)][metric])
			var = np.var(df[(df["Project"] == project) & (df["Method"] == method)][metric])
			proj_results[project] = f"{mean:.3f} , {median:.3f} \\footnotesize{{$\\pm$ {var:.3f}}}"
		method_results.append("\t"*2 + f"{method} & {proj_results["JPetStore"]} & {proj_results["DayTrader"]} & {proj_results["AcmeAir"]} & {proj_results["Plants"]} \\\\")
	print(table_head)
	for result in method_results:
		print(result)
	print(table_tail.replace("metric", metric))
	print()
# Out:
# \center{\textbf{SM,  (higher is better)}}
# \begin{table}[ht]
# 	\centering
# 	\begin{tabular}{lcccc}
# 		\hline
# 		& \multicolumn{4}{c}{\textbf{Projects}} \\
# 		\cline{2-5}
# 		\textbf{Model} & \textbf{JPetStore} & \textbf{DayTrader} & \textbf{AcmeAir} & \textbf{Plants} \\
# 		\hline
# 		Bunch & 0.140 , 0.111 \footnotesize{$\pm$ 0.002} & 0.152 , 0.121 \footnotesize{$\pm$ 0.007} & 0.070 , 0.044 \footnotesize{$\pm$ 0.006} & 0.135 , 0.096 \footnotesize{$\pm$ 0.003} \\
# 		MEM & 0.114 , 0.121 \footnotesize{$\pm$ 0.001} & 0.076 , 0.089 \footnotesize{$\pm$ 0.000} & 0.092 , 0.097 \footnotesize{$\pm$ 0.000} & 0.205 , 0.210 \footnotesize{$\pm$ 0.002} \\
# 		FoSCI & 0.057 , 0.050 \footnotesize{$\pm$ 0.000} & 0.093 , 0.094 \footnotesize{$\pm$ 0.001} & 0.077 , 0.095 \footnotesize{$\pm$ 0.002} & 0.104 , 0.115 \footnotesize{$\pm$ 0.002} \\
# 		Mono2Micro & 0.054 , 0.052 \footnotesize{$\pm$ 0.000} & 0.097 , 0.084 \footnotesize{$\pm$ 0.001} & 0.073 , 0.072 \footnotesize{$\pm$ 0.000} & 0.075 , 0.078 \footnotesize{$\pm$ 0.000} \\
# 		CoGCN & 0.064 , 0.079 \footnotesize{$\pm$ 0.002} & 0.094 , 0.086 \footnotesize{$\pm$ 0.001} & 0.039 , 0.038 \footnotesize{$\pm$ 0.001} & 0.097 , 0.083 \footnotesize{$\pm$ 0.003} \\
# 		HDBSCAN & 0.027 , 0.035 \footnotesize{$\pm$ 0.002} & 0.444 , 0.498 \footnotesize{$\pm$ 0.024} & 0.231 , 0.227 \footnotesize{$\pm$ 0.006} & 0.538 , 0.509 \footnotesize{$\pm$ 0.023} \\
# 		Mo2oM & 0.138 , 0.131 \footnotesize{$\pm$ 0.003} & 0.328 , 0.301 \footnotesize{$\pm$ 0.014} & 0.154 , 0.135 \footnotesize{$\pm$ 0.004} & 0.589 , 0.627 \footnotesize{$\pm$ 0.049} \\
# 		\hline
# 	\end{tabular}
# 	\caption{Model performance on different projects (mean, median ± variance).}
# 	\label{tab:model-performance-SM}
# \end{table}
#
# \center{\textbf{ICP,  (lower is better)}}
#
# \begin{table}[ht]
# 	\centering
# 	\begin{tabular}{lcccc}
# 		\hline
# 		& \multicolumn{4}{c}{\textbf{Projects}} \\
# 		\cline{2-5}
# 		\textbf{Model} & \textbf{JPetStore} & \textbf{DayTrader} & \textbf{AcmeAir} & \textbf{Plants} \\
# 		\hline
# 		Bunch & 0.313 , 0.264 \footnotesize{$\pm$ 0.014} & 0.418 , 0.425 \footnotesize{$\pm$ 0.017} & 0.391 , 0.330 \footnotesize{$\pm$ 0.013} & 0.457 , 0.443 \footnotesize{$\pm$ 0.006} \\
# 		MEM & 0.359 , 0.434 \footnotesize{$\pm$ 0.021} & 0.344 , 0.355 \footnotesize{$\pm$ 0.022} & 0.377 , 0.589 \footnotesize{$\pm$ 0.067} & 0.299 , 0.320 \footnotesize{$\pm$ 0.020} \\
# 		FoSCI & 0.382 , 0.398 \footnotesize{$\pm$ 0.014} & 0.688 , 0.725 \footnotesize{$\pm$ 0.015} & 0.597 , 0.706 \footnotesize{$\pm$ 0.025} & 0.565 , 0.699 \footnotesize{$\pm$ 0.054} \\
# 		Mono2Micro & 0.330 , 0.318 \footnotesize{$\pm$ 0.003} & 0.361 , 0.346 \footnotesize{$\pm$ 0.001} & 0.537 , 0.527 \footnotesize{$\pm$ 0.001} & 0.395 , 0.381 \footnotesize{$\pm$ 0.001} \\
# 		CoGCN & 0.410 , 0.510 \footnotesize{$\pm$ 0.076} & 0.335 , 0.300 \footnotesize{$\pm$ 0.072} & 0.489 , 0.444 \footnotesize{$\pm$ 0.029} & 0.602 , 0.636 \footnotesize{$\pm$ 0.025} \\
# 		HDBSCAN & 0.207 , 0.037 \footnotesize{$\pm$ 0.054} & 0.390 , 0.424 \footnotesize{$\pm$ 0.004} & 0.228 , 0.198 \footnotesize{$\pm$ 0.005} & 0.272 , 0.300 \footnotesize{$\pm$ 0.011} \\
# 		Mo2oM & 0.102 , 0.101 \footnotesize{$\pm$ 0.002} & 0.101 , 0.101 \footnotesize{$\pm$ 0.002} & 0.077 , 0.080 \footnotesize{$\pm$ 0.001} & 0.076 , 0.083 \footnotesize{$\pm$ 0.001} \\
# 		\hline
# 	\end{tabular}
# 	\caption{Model performance on different projects (mean, median ± variance).}
# 	\label{tab:model-performance-ICP}
# \end{table}
#
# \center{\textbf{IFN,  (lower is better)}}
#
# \begin{table}[ht]
# 	\centering
# 	\begin{tabular}{lcccc}
# 		\hline
# 		& \multicolumn{4}{c}{\textbf{Projects}} \\
# 		\cline{2-5}
# 		\textbf{Model} & \textbf{JPetStore} & \textbf{DayTrader} & \textbf{AcmeAir} & \textbf{Plants} \\
# 		\hline
# 		Bunch & 3.740 , 4.250 \footnotesize{$\pm$ 0.610} & 8.485 , 10.400 \footnotesize{$\pm$ 9.869} & 6.903 , 7.333 \footnotesize{$\pm$ 5.366} & 6.794 , 7.667 \footnotesize{$\pm$ 2.181} \\
# 		MEM & 3.079 , 3.429 \footnotesize{$\pm$ 1.365} & 3.162 , 3.357 \footnotesize{$\pm$ 1.134} & 3.133 , 4.333 \footnotesize{$\pm$ 2.160} & 4.042 , 4.750 \footnotesize{$\pm$ 3.280} \\
# 		FoSCI & 3.869 , 3.792 \footnotesize{$\pm$ 0.342} & 6.562 , 5.053 \footnotesize{$\pm$ 13.119} & 4.685 , 4.375 \footnotesize{$\pm$ 0.779} & 4.812 , 4.938 \footnotesize{$\pm$ 0.717} \\
# 		Mono2Micro & 2.951 , 2.322 \footnotesize{$\pm$ 1.698} & 3.969 , 2.421 \footnotesize{$\pm$ 11.443} & 3.920 , 3.625 \footnotesize{$\pm$ 0.812} & 6.441 , 6.000 \footnotesize{$\pm$ 5.589} \\
# 		CoGCN & 1.924 , 2.531 \footnotesize{$\pm$ 1.388} & 2.393 , 2.600 \footnotesize{$\pm$ 3.680} & 2.679 , 2.800 \footnotesize{$\pm$ 0.053} & 5.254 , 4.938 \footnotesize{$\pm$ 2.275} \\
# 		HDBSCAN & 3.758 , 3.000 \footnotesize{$\pm$ 6.033} & 1.385 , 1.375 \footnotesize{$\pm$ 0.013} & 1.619 , 1.600 \footnotesize{$\pm$ 0.025} & 2.603 , 2.286 \footnotesize{$\pm$ 0.394} \\
# 		Mo2oM & 0.224 , 0.066 \footnotesize{$\pm$ 0.173} & 0.295 , 0.132 \footnotesize{$\pm$ 0.236} & 0.125 , 0.059 \footnotesize{$\pm$ 0.041} & 0.760 , 0.500 \footnotesize{$\pm$ 0.932} \\
# 		\hline
# 	\end{tabular}
# 	\caption{Model performance on different projects (mean, median ± variance).}
# 	\label{tab:model-performance-IFN}
# \end{table}
#
# \center{\textbf{NED,  (lower is better)}}
#
# \begin{table}[ht]
# 	\centering
# 	\begin{tabular}{lcccc}
# 		\hline
# 		& \multicolumn{4}{c}{\textbf{Projects}} \\
# 		\cline{2-5}
# 		\textbf{Model} & \textbf{JPetStore} & \textbf{DayTrader} & \textbf{AcmeAir} & \textbf{Plants} \\
# 		\hline
# 		Bunch & 0.222 , 0.000 \footnotesize{$\pm$ 0.099} & 0.601 , 0.639 \footnotesize{$\pm$ 0.017} & 0.282 , 0.154 \footnotesize{$\pm$ 0.088} & 0.115 , 0.000 \footnotesize{$\pm$ 0.027} \\
# 		MEM & 0.936 , 1.000 \footnotesize{$\pm$ 0.029} & 0.976 , 1.000 \footnotesize{$\pm$ 0.001} & 0.678 , 0.464 \footnotesize{$\pm$ 0.069} & 0.398 , 0.288 \footnotesize{$\pm$ 0.075} \\
# 		FoSCI & 0.519 , 0.515 \footnotesize{$\pm$ 0.047} & 0.715 , 0.705 \footnotesize{$\pm$ 0.035} & 0.459 , 0.407 \footnotesize{$\pm$ 0.070} & 0.628 , 0.653 \footnotesize{$\pm$ 0.058} \\
# 		Mono2Micro & 0.196 , 0.216 \footnotesize{$\pm$ 0.022} & 0.355 , 0.338 \footnotesize{$\pm$ 0.034} & 0.443 , 0.429 \footnotesize{$\pm$ 0.003} & 0.077 , 0.038 \footnotesize{$\pm$ 0.008} \\
# 		CoGCN & 0.635 , 0.609 \footnotesize{$\pm$ 0.074} & 0.688 , 0.676 \footnotesize{$\pm$ 0.036} & 0.371 , 0.250 \footnotesize{$\pm$ 0.080} & 0.372 , 0.443 \footnotesize{$\pm$ 0.075} \\
# 		HDBSCAN & 0.828 , 1.000 \footnotesize{$\pm$ 0.057} & 0.927 , 0.922 \footnotesize{$\pm$ 0.006} & 0.781 , 0.863 \footnotesize{$\pm$ 0.026} & 0.832 , 1.000 \footnotesize{$\pm$ 0.062} \\
# 		Mo2oM & 0.556 , 0.516 \footnotesize{$\pm$ 0.032} & 0.650 , 0.626 \footnotesize{$\pm$ 0.026} & 0.404 , 0.319 \footnotesize{$\pm$ 0.051} & 0.344 , 0.302 \footnotesize{$\pm$ 0.075} \\
# 		\hline
# 	\end{tabular}
# 	\caption{Model performance on different projects (mean, median ± variance).}
# 	\label{tab:model-performance-NED}
# \end{table}
